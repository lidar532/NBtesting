# %% [markdown]
# # Testlib
# > A module to put a few functions for testing.

# %% [markdown]
# Use the comment below `#| default_exp testlib` to set the name
# of your exported python file.

# %%
#| default_exp testlib

# %% [markdown]
# Export any imported modules that you need to use when the module is loaded.

# %% [markdown]
# #| hide
# ## Imports

# %%
#| export
import panel as pn
import sys

# %% [markdown]
# The cell below is not exported. It is used to generate tests and docs for your module.

# %%
#| hide
from fastcore.test  import *
from fastcore.utils import *
from nbdev.showdoc  import *
import nbdev

# %% [markdown]
# The cell below is for debugging purposes. Remove the `#| export`
# and rerun nbdev_export to remove it from your module.

# %%
#| export
print('Module debugging Info')
if '__file__' not in globals():
  __file__ = 'Not set'
print(f'  __file__: {__file__}')
if not hasattr(sys, 'prefix'):
  sys.prefix = 'Not set'
print(f'sys.prefix: {sys.prefix}')
print('  sys.path:')
if '__version__' in globals(  ):
  print( f"__version__: {__version__}" )
for p in sys.path:
  print(f'   {p}')
# Out:
# Module debugging Info
#   __file__: Not set
# sys.prefix: /home/wright/miniconda3/envs/dss7
#   sys.path:
#    /home/wright/github-projects/NBtesting/nbs
#    /home/wright/miniconda3/envs/dss7/lib/python311.zip
#    /home/wright/miniconda3/envs/dss7/lib/python3.11
#    /home/wright/miniconda3/envs/dss7/lib/python3.11/lib-dynload
#
#    /home/wright/miniconda3/envs/dss7/lib/python3.11/site-packages

# %% [markdown]
# xxxx

# %%
#| export
import NBtesting.widgets as nbw

# %% [markdown]
# #| hide
# ## Globals

# %%
#| hide
print('Debugging testlib.ipynb')
# Out:
# Debugging testlib.ipynb

# %% [markdown]
# ## Init code
# Runs when module is loaded.

# %%
#| export
pn.extension('floatpanel')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1bfcef04-36d2-4e15-b797-a5535f332adc'>
#   <div id="c5e54195-893c-4c42-a794-8bdf29204d63" data-root-id="1bfcef04-36d2-4e15-b797-a5535f332adc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# #| hide
# ## Funtion definitions

# %% [markdown]
# ### def test_a():

# %%
#| export
def test_a():
  print('This is test_a.')

# %% [markdown]
# ### def test_b():

# %%
#| export
def test_b():
  print('this is test_b.')

# %% [markdown]
# ### def test_widget(parent=None, CallBack_func=None ):

# %%
#| export
def test_widget(parent=None, CallBack_func=None ):
  
  def local_ok_callback( value ):
    txt_w.value = value[0]
    if CallBack_func:
      CallBack_func( value[0] )
    
  def event_h( event ):
    txt_w.value = event.obj.name
    c_w.value   = txt_w.value
    if txt_w.value == 'File':
      nbw.FolderSelector( c_w, CallBack_func = local_ok_callback )
         
  File_b = pn.widgets.Button(name="File")
  a_b    = pn.widgets.Button(name="Run")
  b_b    = pn.widgets.Button(name="Stop")
  c_b    = pn.widgets.Button(name="No Op")
  date_w = pn.widgets.DatePicker(name='Date')
  txt_w  = pn.widgets.StaticText(name='Debug:', value='at start txt.')
  for i in [ File_b, a_b, b_b, c_b]:
    i.on_click( event_h )
  r_w = pn.Row("Master Branch", File_b, a_b, b_b, c_b)
  c_w = pn.Column( date_w, 
                   r_w, 
                   txt_w )
  c_w.Selected_Folder = None
  return c_w

# %% [markdown]
# ## Testing code.

# %%
# Define a call back function for the test_widget.
def my_cb( value ):
  print('my_cb:', value )

r_w = pn.Row("A row")
w  = test_widget( CallBack_func = my_cb )

w.servable()
w
# Out:
# my_cb: /Docker</br>
# Column
#     [0] DatePicker(name='Date')
#     [1] Row
#         [0] Markdown(str)
#         [1] Button(name='File')
#         [2] Button(name='Run')
#         [3] Button(name='Stop')
#         [4] Button(name='No Op')
#     [2] StaticText(name='Debug:', value='at start txt.')

# %%
print(w.Selected_Folder)
# Out:
# /Docker

# %%
def my_cb( value ):
  debug_w.value = value

debug_w = pn.widgets.StaticText(name="Debug", value = 'not set')
tb0 = nbw.TOGGLE_BUTTON(id='b1', on_name='0 Data On', off_name='0 Data off', change_cb=my_cb)
tb1 = nbw.TOGGLE_BUTTON(id='b2', on_name='1 Data On', off_name='1 Data off', initial_state=1, change_cb=my_cb)

# %%
pn.Row(tb0.button, tb1.button, debug_w)
# Out:
# Row
#     [0] Button(button_type='danger', name='0 Data off')
#     [1] Button(button_type='primary', name='1 Data On')
#     [2] StaticText(name='Debug', value='not set')

# %%
tb0.state, tb1.state
# Out:
# (0, 1)
